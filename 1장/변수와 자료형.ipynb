# %%
age=3
print(age)
# Out:
# 3

# %%
age = 20
weight = "75"
pi = 3.14

# %%
type(age)
# Out:
# int

# %%
type(weight)
# Out:
# str

# %%
type(pi)
# Out:
# float

# %%
age/weight
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-8c8d0fca124b> in <module>()
# ----> 1 age/weight
#
# TypeError: unsupported operand type(s) for /: 'int' and 'str'

# %%
greeting = "Hello, World!"
print(greeting)
# Out:
# Hello, World!

# %%
article = '''오늘의 날씨를 말씀드립니다.
중부내륙지방에는 많은 비가 내릴 예정이고
남부해안지방은 쨍쨍합니다.'''

print(article)
# Out:
# 오늘의 날씨를 말씀드립니다.
# 중부내륙지방에는 많은 비가 내릴 예정이고
# 남부해안지방은 쨍쨍합니다.

# %% [markdown]
# ### 리스트 타입

# %%
gu = ['종로구','강남구','용산구',"서대문구"]
print(gu)
# Out:
# ['종로구', '강남구', '용산구', '서대문구']

# %%
type(gu)
# Out:
# list

# %%
gu[2]
# Out:
# '용산구'

# %%
gu[0:3]
# Out:
# ['종로구', '강남구', '용산구']

# %%
gu[:]
# Out:
# ['종로구', '강남구', '용산구', '서대문구']

# %%
gu[:-2]
# Out:
# ['종로구', '강남구']

# %%
gu[-1]
# Out:
# '서대문구'

# %%
gu[-1][0]
# Out:
# '서'

# %%
gu[-1][-1]
# Out:
# '구'

# %%
gu[-1][:3]
# Out:
# '서대문'

# %%
gu[::-1]
# Out:
# ['서대문구', '용산구', '강남구', '종로구']

# %%
gu = ['종로구','강남구','용산구',"서대문구"]
append_gu=['은평구','마포구']

gu.append(append_gu)
print(gu)
# Out:
# ['종로구', '강남구', '용산구', '서대문구', ['은평구', '마포구']]

# %%
gu[4]
# Out:
# ['은평구', '마포구']

# %%
gu = ['종로구','강남구','용산구',"서대문구"]
extend_gu=['은평구','마포구']

gu.extend(extend_gu)
print(gu)
# Out:
# ['종로구', '강남구', '용산구', '서대문구', '은평구', '마포구']

# %%
gu.remove('강남구')
print(gu)
# Out:
# ['종로구', '용산구', '서대문구', '은평구', '마포구']

# %%
gu = ['종로구','강남구','용산구',"서대문구", "용산구", "용산구", "용산구"]
gu.count('용산구')
# Out:
# 4

# %% [markdown]
# ### 딕셔너리 타입

# %%
dict_variable = {"동해섬":"독도", "남해섬":"제주도", "서해섬":"실미도"}
print(dict_variable)
# Out:
# {'동해섬': '독도', '남해섬': '제주도', '서해섬': '실미도'}

# %%
print(dict_variable.keys())
print(dict_variable.values())
# Out:
# dict_keys(['동해섬', '남해섬', '서해섬'])
# dict_values(['독도', '제주도', '실미도'])

# %%
dict_variable["동해섬"]
# Out:
# '독도'

# %%
dict_variable['서울'] ='여의도'

# %%
dict_variable
# Out:
# {'남해섬': '제주도', '동해섬': '독도', '서울': '여의도', '서해섬': '실미도'}

# %%
dict_variable['동해섬'] ='울릉도'

# %%
dict_variable
# Out:
# {'남해섬': '제주도', '동해섬': '울릉도', '서울': '여의도', '서해섬': '실미도'}

# %%
dict_variable_add = {"태평양":"하와이"}
dict_variable.update(dict_variable_add)

# %%
dict_variable
# Out:
# {'남해섬': '제주도', '동해섬': '울릉도', '서울': '여의도', '서해섬': '실미도', '태평양': '하와이'}

# %%
tuple_type = ('아시아','아메리카','아프리카','유럽')
print(tuple_type)
print("데이터 타입 =",type(tuple_type))
# Out:
# ('아시아', '아메리카', '아프리카', '유럽')
# 데이터 타입 = <class 'tuple'>

# %%
tuple_type[0]
# Out:
# '아시아'

# %%
tuple_type[0] = '중앙아시아'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-391809f6cbdf> in <module>()
# ----> 1 tuple_type[0] = '중앙아시아'
#
# TypeError: 'tuple' object does not support item assignment

# %%
set_variable = {'신발','옷','신발','가방','열쇠'}
print(set_variable)
print("데이터 타입 =",type(set_variable))
# Out:
# {'가방', '옷', '열쇠', '신발'}
# 데이터 타입 = <class 'set'>

# %%
set_variable1 = {2,4,6,8,10,12,14,16}
set_variable2 = {4,8,12,16,20,24}

set_variable1.intersection(set_variable2)
# Out:
# {4, 8, 12, 16}

# %%
set_variable1.union(set_variable2)
# Out:
# {2, 4, 6, 8, 10, 12, 14, 16, 20, 24}

# %%
set_variable1.difference(set_variable2)
# Out:
# {2, 6, 10, 14}
