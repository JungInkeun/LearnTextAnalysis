# %%
for i in range(1, 4):
    print("안녕하세요, 반복변수 i 에 저장된 값=", i)
# Out:
# 안녕하세요, 반복변수 i 에 저장된 값= 1
# 안녕하세요, 반복변수 i 에 저장된 값= 2
# 안녕하세요, 반복변수 i 에 저장된 값= 3

# %%
range(1,10)
# Out:
# range(1, 10)

# %%
for i in range(1, 10, 2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for number in range(1, 4):
    print("안녕하세요, 반복변수 number 에 저장된 값=", number)
# Out:
# 안녕하세요, 반복변수 number 에 저장된 값= 1
# 안녕하세요, 반복변수 number 에 저장된 값= 2
# 안녕하세요, 반복변수 number 에 저장된 값= 3

# %%
wish_list = [ '최신형 노트북', '최신형 휴대폰', '최신형 스마트워치', 
              '최신형 태블릿', '라면', '3분요리', '계란' ]
for wish in wish_list:
    print(wish, "을/를 사고 싶어요")
# Out:
# 최신형 노트북 을/를 사고 싶어요
# 최신형 휴대폰 을/를 사고 싶어요
# 최신형 스마트워치 을/를 사고 싶어요
# 최신형 태블릿 을/를 사고 싶어요
# 라면 을/를 사고 싶어요
# 3분요리 을/를 사고 싶어요
# 계란 을/를 사고 싶어요

# %%
wish_list = [ '최신형 노트북', '최신형 휴대폰', '최신형 스마트워치', 
              '최신형 태블릿', '라면', '3분요리', '계란' ]
price_list = [1000000,1200000, 800000, 600000, 3000, 4000, 5000]

for wish, price in zip(wish_list, price_list):
    print(wish, price)
# Out:
# 최신형 노트북 1000000
# 최신형 휴대폰 1200000
# 최신형 스마트워치 800000
# 최신형 태블릿 600000
# 라면 3000
# 3분요리 4000
# 계란 5000

# %%
len(wish_list)
# Out:
# 7

# %%
for wish, price in zip(wish_list, price_list):
    print("{0} 가격은 {1}원입니다.".format(wish, price))
# Out:
# 최신형 노트북 가격은 1000000원입니다.
# 최신형 휴대폰 가격은 1200000원입니다.
# 최신형 스마트워치 가격은 800000원입니다.
# 최신형 태블릿 가격은 600000원입니다.
# 라면 가격은 3000원입니다.
# 3분요리 가격은 4000원입니다.
# 계란 가격은 5000원입니다.

# %%
for i in range(9):
    print(5)
# Out:
# 5
# 5
# 5
# 5
# 5
# 5
# 5
# 5
# 5

# %%
for i in range(9):
    print("{} X {}".format(5, i))
# Out:
# 5 X 0
# 5 X 1
# 5 X 2
# 5 X 3
# 5 X 4
# 5 X 5
# 5 X 6
# 5 X 7
# 5 X 8

# %%
for i in range(9):
    print("{} X {}".format(5, i+1))
# Out:
# 5 X 1
# 5 X 2
# 5 X 3
# 5 X 4
# 5 X 5
# 5 X 6
# 5 X 7
# 5 X 8
# 5 X 9

# %%
for i in range(1, 10):
    print("{} X {}".format(5, i))
# Out:
# 5 X 1
# 5 X 2
# 5 X 3
# 5 X 4
# 5 X 5
# 5 X 6
# 5 X 7
# 5 X 8
# 5 X 9

# %%
for i in range(9):
    print("{} X {} = {}".format(5, i+1, 5*(i+1)))
# Out:
# 5 X 1 = 5
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45

# %%
print(5%2)
print(10%2)
# Out:
# 1
# 0

# %%
for i in range(9):
    result = 5*(i+1)
    if result % 2 ==0:
        print("{} X {} = {}".format(5, i+1, 5*(i+1)))
# Out:
# 5 X 2 = 10
# 5 X 4 = 20
# 5 X 6 = 30
# 5 X 8 = 40

# %%
for i in range(9):
    result = 5*(i+1)
    if result % 2 ==0:
        print("{} X {} = {}".format(5, i+1, 5*(i+1)))
    else:
        print("{}는 홀수입니다.".format(result))
# Out:
# 5는 홀수입니다.
# 5 X 2 = 10
# 15는 홀수입니다.
# 5 X 4 = 20
# 25는 홀수입니다.
# 5 X 6 = 30
# 35는 홀수입니다.
# 5 X 8 = 40
# 45는 홀수입니다.

# %%
days = ['일요일','월요일','화요일','수요일','목요일','금요일','토요일']
members = ['홍길동','고길동','임꺽정','콩쥐']

for day in days:
    if (day == '월요일'):
        for member in members:
            print("{}님 한주를 시작하는 {} 입니다. 기운차고 행복한 한주되시기 바랍니다.".format(member, day))
    elif (day == '금요일'):
        for member in members:
            print("{}님 한주 마무리는 잘 하셨나요? 즐거운 주말되시기 바랍니다.".format(member))
# Out:
# 홍길동님 한주를 시작하는 월요일 입니다. 기운차고 행복한 한주되시기 바랍니다.
# 고길동님 한주를 시작하는 월요일 입니다. 기운차고 행복한 한주되시기 바랍니다.
# 임꺽정님 한주를 시작하는 월요일 입니다. 기운차고 행복한 한주되시기 바랍니다.
# 콩쥐님 한주를 시작하는 월요일 입니다. 기운차고 행복한 한주되시기 바랍니다.
# 홍길동님 한주 마무리는 잘 하셨나요? 즐거운 주말되시기 바랍니다.
# 고길동님 한주 마무리는 잘 하셨나요? 즐거운 주말되시기 바랍니다.
# 임꺽정님 한주 마무리는 잘 하셨나요? 즐거운 주말되시기 바랍니다.
# 콩쥐님 한주 마무리는 잘 하셨나요? 즐거운 주말되시기 바랍니다.

# %% [markdown]
# ### 컴프리핸션(Comprehension)

# %%
even = []
for i in range(5, 46, 5):
    if  i % 2 ==0:
        even.append(i)

print(even)
# Out:
# [10, 20, 30, 40]

# %%
even = [ i for i in range(5, 46, 5) if i % 2 ==0]
print(even)
# Out:
# [10, 20, 30, 40]

# %% [markdown]
# ### While 반복문

# %%
i = 0
sum_value = 0
while (sum_value<100):
    i = i + 1
    sum_value += i

    print("더할값 :{}  누적값 : {}".format(i, sum_value))
print()
print("최종값", sum_value)
# Out:
# 더할값 :1  누적값 : 1
# 더할값 :2  누적값 : 3
# 더할값 :3  누적값 : 6
# 더할값 :4  누적값 : 10
# 더할값 :5  누적값 : 15
# 더할값 :6  누적값 : 21
# 더할값 :7  누적값 : 28
# 더할값 :8  누적값 : 36
# 더할값 :9  누적값 : 45
# 더할값 :10  누적값 : 55
# 더할값 :11  누적값 : 66
# 더할값 :12  누적값 : 78
# 더할값 :13  누적값 : 91
# 더할값 :14  누적값 : 105
#
# 최종값 105
